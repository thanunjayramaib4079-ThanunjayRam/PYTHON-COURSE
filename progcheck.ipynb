# %% [markdown]
# <a href="https://colab.research.google.com/github/thanunjayramaib4079-ThanunjayRam/PYTHON-COURSE/blob/main/progcheck.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=5
b=6
c=a*b
print(c)
# Out:
# 30
