# %% [markdown]
# <a href="https://colab.research.google.com/github/thanunjayramaib4079-ThanunjayRam/PYTHON-COURSE/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#program-11(Write a Python Program to Check if a Number is Positive, Negative or Zero)
num=int(input("enter ur num:"))
if num>0:
  print(" num is positive number ")
elif num==0:
  print("num is zero")
else:
  print('num is negative number')
# Out:
# enter ur num:-2
# num is negative number

# %%
#program-12(Write a Python Program to Check if a Number is Odd or Even)
num=int(input("enter ur num: "))
if num%2==0:
  print("num is even")
else:
  print("num is odd")
# Out:
# enter ur num: 20
# num is even

# %%
#program-13(Write a Python Program to Check Leap Year)
year=int(input("enter ur year: "))
if year%4==0 & year%400==0:
  print("given year is a leap year")
else:
  print("given year is not a leap year ")
# Out:
# enter ur year: 2008
# given year is a leap year

# %%
#program-14(Write a Python Program to Check Prime Number)
import math

def is_prime(n):
    # Condition 1: Number must be greater than 1
    if n <= 1:
        return False

    # Check divisibility from 2 to √n
    for i in range(2, int(math.sqrt(n)) + 1):
        if n % i == 0:
            return False

    return True


# Take input from user
num = int(input("Enter a number: "))

if is_prime(num):
    print(num, "is a Prime number")
else:
    print(num, "is NOT a Prime number")
# Out:
# Enter a number: 25
# 25 is NOT a Prime number

# %%
#program-15(Write a Python Program to Print all Prime Numbers in an Interval of 1-10)
lower = 1
upper = 10
print("Prime numbers between", lower, "and", upper, "are:")
for num in range(lower, upper + 1):
  # all prime numbers are greater than 1
  if num > 1:
    for i in range(2, num):
       if (num % i) == 0:
         break
    else:
      print(num)
# Out:
# Prime numbers between 1 and 10 are:
# 2
# 3
# 5
# 7
